# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhp4/Assignment-1-Q23-Basic-Statistics-Level-1-/blob/main/DS_ASSG_RANDOM_FOREST_COMPANY_UPDATED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import datasets,tree
from sklearn.tree import export_graphviz 
from sklearn import externals
from io import StringIO
import pydotplus
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt

# %% [markdown]
# ## __1 - Business Problem__
# ___A cloth manufacturing company is interested to know about the segment or attributes causes high sale___

# %% [markdown]
# ## __2 - Data collection and description__

# %%
df = pd.read_csv("Company_Data.csv")

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#    Sales  CompPrice  Income  Advertising  ...  Age  Education Urban   US
# 0   9.50        138      73           11  ...   42         17   Yes  Yes
# 1  11.22        111      48           16  ...   65         10   Yes  Yes
# 2  10.06        113      35           10  ...   59         12   Yes  Yes
# 3   7.40        117     100            4  ...   55         14   Yes  Yes
# 4   4.15        141      64            3  ...   38         13   Yes   No
#
# [5 rows x 11 columns]

# %%
df1.describe().T
# Out:
#              count        mean         std  ...     50%     75%     max
# Sales        400.0    7.496325    2.824115  ...    7.49    9.32   16.27
# CompPrice    400.0  124.975000   15.334512  ...  125.00  135.00  175.00
# Income       400.0   68.657500   27.986037  ...   69.00   91.00  120.00
# Advertising  400.0    6.635000    6.650364  ...    5.00   12.00   29.00
# Population   400.0  264.840000  147.376436  ...  272.00  398.50  509.00
# Price        400.0  115.795000   23.676664  ...  117.00  131.00  191.00
# Age          400.0   53.322500   16.200297  ...   54.50   66.00   80.00
# Education    400.0   13.900000    2.620528  ...   14.00   16.00   18.00
#
# [8 rows x 8 columns]

# %%
df1.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
df1.dtypes
# Out:
# Sales          float64
# CompPrice        int64
# Income           int64
# Advertising      int64
# Population       int64
# Price            int64
# ShelveLoc       object
# Age              int64
# Education        int64
# Urban           object
# US              object
# dtype: object

# %% [markdown]
# ### Outlier Check

# %%
ax = sns.boxplot(df1['Sales'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### The data has 2 outlier instances

# %%
plt.rcParams["figure.figsize"] = 9,5

# %%
plt.figure(figsize=(16,5))
print("Skew: {}".format(df1['Sales'].skew()))
print("Kurtosis: {}".format(df1['Sales'].kurtosis()))
ax = sns.kdeplot(df1['Sales'],shade=True,color='g')
plt.xticks([i for i in range(0,20,1)])
plt.show()
# Out:
# Skew: 0.18556036318721578
# Kurtosis: -0.08087736743346197

# %% [markdown]
# ### The data is Skwed on the right
# ### The data has negative Kurtosis

# %%
obj_colum = df1.select_dtypes(include='object').columns.tolist()

# %%
plt.figure(figsize=(16,10))
for i,col in enumerate(obj_colum,1):
    plt.subplot(2,2,i)
    sns.countplot(data=df1,y=col)
    plt.subplot(2,2,i+1)
    df1[col].value_counts(normalize=True).plot.bar()
    plt.ylabel(col)
    plt.xlabel('% distribution per category')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
num_columns = df1.select_dtypes(exclude='object').columns.tolist()

# %%
plt.figure(figsize=(18,40))
for i,col in enumerate(num_columns,1):
    plt.subplot(8,4,i)
    sns.kdeplot(df[col],color='g',shade=True)
    plt.subplot(8,4,i+10)
    df[col].plot.box()
plt.tight_layout() 
plt.show()
num_data = df[num_columns]
pd.DataFrame(data=[num_data.skew(),num_data.kurtosis()],index=['skewness','kurtosis'])
# Out:
#              Sales  CompPrice    Income  ...     Price       Age  Education
# skewness  0.185560  -0.042755  0.049444  ... -0.125286 -0.077182   0.044007
# kurtosis -0.080877   0.041666 -1.085289  ...  0.451885 -1.134392  -1.298332
#
# [2 rows x 8 columns]

# %%
corr = df1.corr()

# %%
df1 = pd.get_dummies(df1, columns = ['ShelveLoc','Urban','US'])

# %%
corr = df1.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)

# %% [markdown]
# ## __3 - Random Forest Model__

# %% [markdown]
# ### Since the target variable is continious, we create a class of the value based on the mean
# ### <= 7.49 == "Small" and > 7.49 == "large"

# %%
df1["sales"]="small"
df1.loc[df1["Sales"]>7.49,"sales"]="large"
df1.drop(["Sales"],axis=1,inplace=True)

# %%
X = df1.iloc[:,0:14]
y = df1.iloc[:,14]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
y_train.value_counts()
# Out:
# small    171
# large    149
# Name: sales, dtype: int64

# %%
model =RF(n_jobs=4,n_estimators = 150, oob_score =True,criterion ='entropy') 
model.fit(x_train,y_train)
model.oob_score_
# Out:
# 0.815625

# %%
pred_train = model.predict(x_train)

# %%
accuracy_score(y_train,pred_train)
# Out:
# 1.0

# %%
confusion_matrix(y_train,pred_train)
# Out:
# array([[149,   0],
#        [  0, 171]])

# %%
pred_test = model.predict(x_test)

# %%
accuracy_score(y_test,pred_test)
# Out:
# 0.8

# %%
confusion_matrix(y_test,pred_test)
# Out:
# array([[38, 12],
#        [ 4, 26]])

# %%
df_t=pd.DataFrame({'Actual':y_test, 'Predicted':pred_test})

# %%
df_t
# Out:
#     Actual Predicted
# 368  large     large
# 134  small     small
# 232  large     large
# 357  large     large
# 212  large     large
# ..     ...       ...
# 105  small     large
# 52   large     small
# 25   large     large
# 336  small     small
# 304  large     large
#
# [80 rows x 2 columns]

# %%
cols = list(df1.columns)

# %%
predictors = cols[0:14]
target = cols[14]

# %%
tree1 = model.estimators_[20]

# %%
dot_data = StringIO()

# %%
export_graphviz(tree1, out_file = dot_data, feature_names =predictors, class_names = target, filled =True,rounded=True,impurity =False,proportion=False,precision =2)

# %%
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

# %%
graph.write_png('company_full.png')
# Out:
# True

# %% [markdown]
# ## __4 - Conclusion__

# %% [markdown]
# ### Since the accuracy of the Training set is 100% we test the accurancy on the test data which is 76%
# ### As seen in the confusion matrix of Test data 61 instances are presdected correctly and 19 instances are not

# %%
rf_small = RF(n_estimators=10, max_depth = 3)

# %%
rf_small.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=10)

# %%
tree_small = rf_small.estimators_[5]

# %%
export_graphviz(tree_small, out_file = dot_data, feature_names = predictors, rounded = True, precision = 1)

# %%
graph_small = pydotplus.graph_from_dot_data(dot_data.getvalue())

# %%
graph.write_png('company_small.png')
# Out:
# True

# %%
img = mpimg.imread('company_small.png')

# %%
plt.imshow(img)

# %%
model.feature_importances_
# Out:
# array([0.11844911, 0.10869317, 0.11104799, 0.092797  , 0.2267431 ,
#        0.11071008, 0.06269131, 0.0362993 , 0.05796266, 0.02153397,
#        0.01385944, 0.01303194, 0.01292425, 0.01325667])

# %%
fi = pd.DataFrame({'feature': list(x_train.columns),
                   'importance': model.feature_importances_}).\
                    sort_values('importance', ascending = False)

# %%
fi
# Out:
#              feature  importance
# 4              Price    0.226743
# 0          CompPrice    0.118449
# 2        Advertising    0.111048
# 5                Age    0.110710
# 1             Income    0.108693
# 3         Population    0.092797
# 6          Education    0.062691
# 8     ShelveLoc_Good    0.057963
# 7      ShelveLoc_Bad    0.036299
# 9   ShelveLoc_Medium    0.021534
# 10          Urban_No    0.013859
# 13            US_Yes    0.013257
# 11         Urban_Yes    0.013032
# 12             US_No    0.012924

# %% [markdown]
# ### As seen in the above table Price is most important feature
