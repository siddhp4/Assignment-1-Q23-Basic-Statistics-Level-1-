# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhp4/Assignment-1-Q23-Basic-Statistics-Level-1-/blob/main/DA_ASSG_KNN_GLASS_UPDATED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
sns.set()

# %%
df = pd.read_csv("glass.csv")

# %%
df1 = df.copy()

# %%
df1.loc[df['Type'] == 1, 'Type'] = 'building_windows_float_processed'
df1.loc[df['Type'] == 2, 'Type'] = 'building_windows_non_float_processed' 
df1.loc[df['Type'] == 3, 'Type'] = 'vehicle_windows_float_processed' 
df1.loc[df['Type'] == 4, 'Type'] = 'vehicle_windows_non_float_processed' 
df1.loc[df['Type'] == 5, 'Type'] = 'containers' 
df1.loc[df['Type'] == 6, 'Type'] = 'tableware' 
df1.loc[df['Type'] == 7, 'Type'] = 'headlamps'

# %%
df1.head()
# Out:
#         RI     Na    Mg    Al  ...    Ca   Ba   Fe                              Type
# 0  1.52101  13.64  4.49  1.10  ...  8.75  0.0  0.0  building_windows_float_processed
# 1  1.51761  13.89  3.60  1.36  ...  7.83  0.0  0.0  building_windows_float_processed
# 2  1.51618  13.53  3.55  1.54  ...  7.78  0.0  0.0  building_windows_float_processed
# 3  1.51766  13.21  3.69  1.29  ...  8.22  0.0  0.0  building_windows_float_processed
# 4  1.51742  13.27  3.62  1.24  ...  8.07  0.0  0.0  building_windows_float_processed
#
# [5 rows x 10 columns]

# %%
df1.describe()
# Out:
#                RI          Na          Mg  ...          Ca          Ba          Fe
# count  214.000000  214.000000  214.000000  ...  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533  ...    8.956963    0.175047    0.057009
# std      0.003037    0.816604    1.442408  ...    1.423153    0.497219    0.097439
# min      1.511150   10.730000    0.000000  ...    5.430000    0.000000    0.000000
# 25%      1.516523   12.907500    2.115000  ...    8.240000    0.000000    0.000000
# 50%      1.517680   13.300000    3.480000  ...    8.600000    0.000000    0.000000
# 75%      1.519157   13.825000    3.600000  ...    9.172500    0.000000    0.100000
# max      1.533930   17.380000    4.490000  ...   16.190000    3.150000    0.510000
#
# [8 rows x 9 columns]

# %%
sns.factorplot('Type', data=df1, kind="count",size = 5,aspect = 2)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #### As shown in the graphs above, majority of the glass types are building_windows_float_processed and building_windows_non_float_processed, followed by headlamps

# %%
df1.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
df1.plot(kind='box', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# ##Finding correlation between the variables in the data

# %%
cor = df1.corr(method='pearson')

# %%
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_76b48730_7da2_11ec_b084_0242ac1c0002row0_col0,#T_76b48730_7da2_11ec_b084_0242ac1c0002row1_col1,#T_76b48730_7da2_11ec_b084_0242ac1c0002row2_col2,#T_76b48730_7da2_11ec_b084_0242ac1c0002row3_col3,#T_76b48730_7da2_11ec_b084_0242ac1c0002row4_col4,#T_76b48730_7da2_11ec_b084_0242ac1c0002row5_col5,#T_76b48730_7da2_11ec_b084_0242ac1c0002row6_col6,#T_76b48730_7da2_11ec_b084_0242ac1c0002row7_col7,#T_76b48730_7da2_11ec_b084_0242ac1c0002row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row0_col1{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row0_col2{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row0_col3{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row0_col4,#T_76b48730_7da2_11ec_b084_0242ac1c0002row1_col8,#T_76b48730_7da2_11ec_b084_0242ac1c0002row2_col1,#T_76b48730_7da2_11ec_b084_0242ac1c0002row2_col3,#T_76b48730_7da2_11ec_b084_0242ac1c0002row2_col6,#T_76b48730_7da2_11ec_b084_0242ac1c0002row2_col7,#T_76b48730_7da2_11ec_b084_0242ac1c0002row4_col0,#T_76b48730_7da2_11ec_b084_0242ac1c0002row6_col1,#T_76b48730_7da2_11ec_b084_0242ac1c0002row6_col5,#T_76b48730_7da2_11ec_b084_0242ac1c0002row7_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row0_col5{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row0_col6{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row0_col7{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row0_col8{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row1_col0,#T_76b48730_7da2_11ec_b084_0242ac1c0002row7_col6{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row1_col2,#T_76b48730_7da2_11ec_b084_0242ac1c0002row7_col8{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row1_col3{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row1_col4{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row1_col5{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row1_col6{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row1_col7{
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row2_col0{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row2_col4,#T_76b48730_7da2_11ec_b084_0242ac1c0002row2_col5{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row2_col8,#T_76b48730_7da2_11ec_b084_0242ac1c0002row4_col7{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row3_col0,#T_76b48730_7da2_11ec_b084_0242ac1c0002row5_col6{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row3_col1{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row3_col2,#T_76b48730_7da2_11ec_b084_0242ac1c0002row5_col1{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row3_col4,#T_76b48730_7da2_11ec_b084_0242ac1c0002row7_col0{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row3_col5{
#             background-color:  #dadce0;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row3_col6{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row3_col7,#T_76b48730_7da2_11ec_b084_0242ac1c0002row7_col3{
#             background-color:  #f6bda2;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row3_col8{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row4_col1,#T_76b48730_7da2_11ec_b084_0242ac1c0002row4_col6,#T_76b48730_7da2_11ec_b084_0242ac1c0002row5_col0{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row4_col2,#T_76b48730_7da2_11ec_b084_0242ac1c0002row6_col4{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row4_col3{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row4_col5{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row4_col8{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row5_col2{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row5_col3{
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row5_col4{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row5_col7{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row5_col8{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row6_col0{
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row6_col2{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row6_col3{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row6_col7{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row6_col8{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row7_col1{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row7_col4{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row7_col5{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row8_col0{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row8_col1{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row8_col2{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row8_col3{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row8_col4,#T_76b48730_7da2_11ec_b084_0242ac1c0002row8_col7{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b084_0242ac1c0002row8_col5{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_76b48730_7da2_11ec_b08

# %% [markdown]
# ### We can use PCA to reduce the high correlated variables,from the above graph

# %% [markdown]
# ### Finding optimal number of K

# %%
X = np.array(df1.iloc[:,3:5])
y = np.array(df1['Type'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %%
k_values = np.arange(1,25)
train_accuracy = []
test_accuracy = []

# %%
for i, k in enumerate(k_values):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    train_accuracy.append(knn.score(X_train, y_train))
    test_accuracy.append(knn.score(X_test, y_test))

# %%
plt.figure(figsize=[13,8])
plt.plot(k_values, test_accuracy, label = 'Testing Accuracy')
plt.plot(k_values, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(k_values)
plt.show()

# %% [markdown]
# ### we can see that k=4 produces the most accurate results

# %% [markdown]
# ### Applying the algorithm

# %%
knn = KNeighborsClassifier(n_neighbors=4)

# %%
knn.fit(X_train, y_train)
y_pred_KNeighborsClassifier = knn.predict(X_test)

# %%
scores = []
cv_scores = []

# %%
score = accuracy_score(y_pred_KNeighborsClassifier,y_test)
scores.append(score)

# %%
score_knn=cross_val_score(knn, X,y, cv=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   UserWarning,

# %%
score_knn.mean()
# Out:
# 0.6127705627705629

# %%
score_knn.std()*2
# Out:
# 0.23547117559816877

# %%
cv_score = score_knn.mean()

# %%
cv_scores.append(cv_score)

# %%
cv_scores
# Out:
# [0.6127705627705629]

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Support Vector Machine Accuracy: 0.60 (+/- 0.21)
